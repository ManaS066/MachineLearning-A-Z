# %% [markdown]
# # Simple Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.linear_model as aa
import sklearn.model_selection as s

# %% [markdown]
# ## Importing the dataset

# %%
ds = pd.read_csv("run.csv")
x=ds.iloc[:,:-1].values
y= ds.iloc[:,-1].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
x_train,x_test,y_train,y_test  = s.train_test_split(x,y,test_size = 0.2,random_state=1)

# %% [markdown]
# ## Training the Simple Linear Regression model on the Training set

# %%
reg = aa.LinearRegression()  # createing instance of the class
reg.fit(x_train,y_train)  # training the model on the training set
# Out:
# LinearRegression()

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = reg.predict(x_test)
print(y_pred)
# Out:
# [8.35714286 5.21428571]

# %% [markdown]
# ## Visualising the Training set results

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train, reg.predict(x_train),color = 'blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %% [markdown]
# ## Visualising the Test set results

# %%
plt.scatter(x_test,y_test,color='red')
plt.plot(x_test,y_pred,color = 'blue')
plt.title('Salary vs Experience (Testing set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
plt.scatter(x_train,y_train,color='red')
plt.scatter(x_test,y_test,color='black')
plt.plot(x_train, reg.predict(x_train),color = 'blue')
plt.plot(x_test, y_pred,color = 'black')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
data = [[12],[13],[14],[15],[16],[17],[18],[19],[20]]

# %%
print(data)
# Out:
# [[12], [13], [14], [15], [16], [17], [18], [19], [20]]

# %%
print(reg.predict(data))
# Out:
# [36.64285714 39.78571429 42.92857143 46.07142857 49.21428571 52.35714286
#  55.5        58.64285714 61.78571429]

# %%
plt.scatter(data,reg.predict(data),color="red")
plt.plot(data,reg.predict(data),color="black")
plt.show()
